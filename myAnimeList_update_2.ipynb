# %%
import pandas as pd


df_anime = pd.read_csv('MyAnimeList\\anime_cleaned.csv')
df_users = pd.read_csv('MyAnimeList\\users_cleaned.csv')
df_lists = pd.read_csv('MyAnimeList\\animelists_cleaned.csv')
df_synopsis = pd.read_csv('NewAnime\\anime-filtered.csv')
df_updated_synopsis=pd.read_csv('anime-with-description.csv')
df_anime.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# ...

# %%
df_users.head()
# Out:
#          username  user_id  user_watching  user_completed  user_onhold  \
# 0        karthiga  2255153              3              49            1
# 1       Damonashu    37326             45             195           27
# 2           bskai   228342             25             414            2
# 3  terune_uzumaki   327311              5               5            0
# 4           Bas_G  5015094             35             114            6
#
#    user_dropped  user_plantowatch  user_days_spent_watching  gender  \
# 0             0                 0                 55.091667  Female
# 1            25                59                 82.574306    Male
# 2             5                11                159.483333    Male
# 3             0                 0                 11.394444  Female
# 4            20               175                 30.458333    Male
#
#               location           birth_date  access_rank            join_date  \
# ...

# %%
df_lists.head()
# Out:
#    username  anime_id  my_watched_episodes my_start_date my_finish_date  \
# 0  karthiga        21                  586    0000-00-00     0000-00-00
# 1  karthiga        59                   26    0000-00-00     0000-00-00
# 2  karthiga        74                   26    0000-00-00     0000-00-00
# 3  karthiga       120                   26    0000-00-00     0000-00-00
# 4  karthiga       178                   26    0000-00-00     0000-00-00
#
#    my_score  my_status  my_rewatching  my_rewatching_ep      my_last_updated  \
# 0         9          1            NaN                 0  2013-03-03 10:52:53
# 1         7          2            NaN                 0  2013-03-10 13:54:51
# 2         7          2            NaN                 0  2013-04-27 16:43:35
# 3         7          2            NaN                 0  2013-03-03 10:53:57
# 4         7          2            0.0                 0  2013-03-27 15:59:13
#
#   my_tags
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
anime=pd.concat([df_anime[['anime_id','image_url','type','source','episodes','status','airing','aired','duration','members','favorites','background','premiered','broadcast','related','producer','licensor','studio','genre','opening_theme','ending_theme']]], axis=1)
anime['ranking_id'] = range(1, len(anime) + 1)
anime['title_id'] = range(1, len(anime) + 1)
anime
# Out:
#       anime_id                                          image_url type  \
# 0        11013  https://myanimelist.cdn-dena.com/images/anime/...   TV
# 1         2104  https://myanimelist.cdn-dena.com/images/anime/...   TV
# 2         5262  https://myanimelist.cdn-dena.com/images/anime/...   TV
# 3          721  https://myanimelist.cdn-dena.com/images/anime/...   TV
# 4        12365  https://myanimelist.cdn-dena.com/images/anime/...   TV
# ...        ...                                                ...  ...
# 6663     37405  https://myanimelist.cdn-dena.com/images/anime/...  OVA
# 6664     37886  https://myanimelist.cdn-dena.com/images/anime/...  ONA
# 6665     37255  https://myanimelist.cdn-dena.com/images/anime/...  OVA
# 6666     35229  https://myanimelist.cdn-dena.com/images/anime/...  ONA
# 6667     36315  https://myanimelist.cdn-dena.com/images/anime/...  OVA
#
#             source  episodes            status  airing  \
# 0            Manga        12   Finished Airing   False
# ...

# %%
title=pd.concat([df_anime[['title','title_english','title_japanese','title_synonyms']]])
title['title_id']=range(1, len(title) + 1)
title
# Out:
#                                                   title  \
# 0                                         Inu x Boku SS
# 1                                      Seto no Hanayome
# 2                                    Shugo Chara!! Doki
# 3                                         Princess Tutu
# 4                                   Bakuman. 3rd Season
# ...                                                 ...
# 6663                            Dokidoki Little Ooyasan
# 6664                        Wo Shi Jiang Xiaobai (2018)
# 6665              Genki Genki Non-tan: Obake Mura Meiro
# 6666                                Mr. Men Little Miss
# 6667  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                   title_english                      title_japanese  \
# 0     Inu X Boku Secret Service                              妖狐×僕SS
# 1         My Bride is a Mermaid                               瀬戸の花嫁
# 2            Shugo Chara!! Doki                         しゅごキャラ！！どきっ
# ...

# %%
ranking=pd.concat([df_anime[['rating','score','rank']]])
ranking['ranking_id']=range(1, len(ranking) + 1)
ranking
# Out:
#                          rating  score     rank  ranking_id
# 0     PG-13 - Teens 13 or older   7.63   1274.0           1
# 1     PG-13 - Teens 13 or older   7.89    727.0           2
# 2                 PG - Children   7.55   1508.0           3
# 3     PG-13 - Teens 13 or older   8.21    307.0           4
# 4     PG-13 - Teens 13 or older   8.67     50.0           5
# ...                         ...    ...      ...         ...
# 6663                Rx - Hentai   9.52      NaN        6664
# 6664  PG-13 - Teens 13 or older   0.00  12719.0        6665
# 6665               G - All Ages   4.20  10253.0        6666
# 6666               G - All Ages   4.57  11396.0        6667
# 6667               G - All Ages   7.00  11396.0        6668
#
# [6668 rows x 4 columns]

# %%
users=pd.concat([df_users[['user_id','username','user_watching','user_completed','user_onhold','user_dropped','user_plantowatch','user_days_spent_watching','birth_date','access_rank','join_date','last_online','stats_mean_score','stats_rewatched','stats_episodes']]])
users['location_id']=range(1, len(users) + 1)
users['gender_id']=range(1, len(users) + 1)
users
# Out:
#         user_id        username  user_watching  user_completed  user_onhold  \
# 0       2255153        karthiga              3              49            1
# 1         37326       Damonashu             45             195           27
# 2        228342           bskai             25             414            2
# 3        327311  terune_uzumaki              5               5            0
# 4       5015094           Bas_G             35             114            6
# ...         ...             ...            ...             ...          ...
# 108706   797785          isoann             14             213           11
# 108707  1396285        bumcakee             13             116            5
# 108708  2478991       Scarlet95              6             103           10
# 108709  3975907        Torasori             22             239            0
# 108710  1289601          HMicca             11              73            2
#
# ...

# %%
gender=pd.concat([df_users[['gender']]])
gender['gender_id']=range(1, len(gender) + 1)
gender
# Out:
#         gender  gender_id
# 0       Female          1
# 1         Male          2
# 2         Male          3
# 3       Female          4
# 4         Male          5
# ...        ...        ...
# 108706    Male     108707
# 108707  Female     108708
# 108708  Female     108709
# 108709    Male     108710
# 108710  Female     108711
#
# [108711 rows x 2 columns]

# %%
location=pd.concat([df_users[['location']]])
location['location_id']=range(1, len(location) + 1)
location
# Out:
#                       location  location_id
# 0              Chennai, India             1
# 1             Detroit,Michigan            2
# 2              Nayarit, Mexico            3
# 3            Malaysia, Kuantan            4
# 4          Nijmegen, Nederland            5
# ...                        ...          ...
# 108706                 Poland:       108707
# 108707  nhollywood, california       108708
# 108708                 Belgium       108709
# 108709            Latvia, Riga       108710
# 108710     Birmingham, England       108711
#
# [108711 rows x 2 columns]

# %%
userAnimeRating=pd.concat([df_lists[['anime_id','my_watched_episodes','my_start_date','my_finish_date','my_score','my_status','my_rewatching','my_rewatching_ep','my_last_updated','my_tags']]])
userAnimeRating = df_lists.merge(df_users[['user_id', 'username']], on='username', how='left')
userAnimeRating
# Out:
#                   username  anime_id  my_watched_episodes my_start_date  \
# 0                 karthiga        21                  586    0000-00-00
# 1                 karthiga        59                   26    0000-00-00
# 2                 karthiga        74                   26    0000-00-00
# 3                 karthiga       120                   26    0000-00-00
# 4                 karthiga       178                   26    0000-00-00
# ...                    ...       ...                  ...           ...
# 31284025     Yokonightcore     15611                   48    2014-00-00
# 31284026     Yokonightcore     27815                   22    0000-00-00
# 31284027            wargod      5945                   39    0000-00-00
# 31284028  JMc_SetoKai_LoVe      1316                   52    0000-00-00
# 31284029    hinogurl_mikha      1744                   58    0000-00-00
#
#          my_finish_date  my_score  my_status  my_rewatching  my_rewatching_ep  \
# ...

# %%
df_synopsis
# Out:
#        anime_id                             Name  Score  \
# 0             1                     Cowboy Bebop   8.78
# 1             5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2             6                           Trigun   8.24
# 3             7               Witch Hunter Robin   7.27
# 4             8                   Bouken Ou Beet   6.98
# ...         ...                              ...    ...
# 14947     48481  Daomu Biji Zhi Qinling Shen Shu   6.51
# 14948     48483                     Mieruko-chan   6.51
# 14949     48488  Higurashi no Naku Koro ni Sotsu   6.51
# 14950     48491      Yama no Susume: Next Summit   6.51
# 14951     48492                    Scarlet Nexus   6.51
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
anime = df_anime.merge(df_updated_synopsis[['title', 'synopsis']], left_on='title', right_on='title', how='left')
anime
# Out:
#       anime_id                                              title  \
# 0        11013                                      Inu x Boku SS
# 1         2104                                   Seto no Hanayome
# 2         5262                                 Shugo Chara!! Doki
# 3          721                                      Princess Tutu
# 4        12365                                Bakuman. 3rd Season
# ...        ...                                                ...
# 6663     37405                            Dokidoki Little Ooyasan
# 6664     37886                        Wo Shi Jiang Xiaobai (2018)
# 6665     37255              Genki Genki Non-tan: Obake Mura Meiro
# 6666     35229                                Mr. Men Little Miss
# 6667     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                   title_english                      title_japanese  \
# 0     Inu X Boku Secret Service                              妖狐×僕SS
# ...

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def tokenize_and_lemmatize(text):
    if not isinstance(text, str):  
        return text  
    
    tokens = word_tokenize(text)
    lemmatized = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized  

anime['lemmatized_synopsis'] = anime['synopsis'].apply(tokenize_and_lemmatize)

anime
# Out:
#       anime_id                                              title  \
# 0        11013                                      Inu x Boku SS
# 1         2104                                   Seto no Hanayome
# 2         5262                                 Shugo Chara!! Doki
# 3          721                                      Princess Tutu
# 4        12365                                Bakuman. 3rd Season
# ...        ...                                                ...
# 6663     37405                            Dokidoki Little Ooyasan
# 6664     37886                        Wo Shi Jiang Xiaobai (2018)
# 6665     37255              Genki Genki Non-tan: Obake Mura Meiro
# 6666     35229                                Mr. Men Little Miss
# 6667     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                   title_english                      title_japanese  \
# 0     Inu X Boku Secret Service                              妖狐×僕SS
# ...
